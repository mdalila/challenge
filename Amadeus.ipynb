# %% [markdown]
# ## Amadeus Challenge

# %%
# %matplotlib inline

import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Exercise 1 : number of lines in each file

# %%
path1 = 'C:\Users\dmessedi\Desktop\Amadeus\\bookings.csv'

# %%
path2 = 'C:\Users\dmessedi\Desktop\Amadeus\\searches.csv'

# %%
path_1 = '/Users/dalilamessedi/Desktop/Data/bookings.csv'

# %%
path_2 = '/Users/dalilamessedi/Desktop/Data/searches.csv'

# %%
# Bookings file 
with open(path1) as f:
      print len(f.readlines())
# Out:
# 10000011

# %%
# Searches file
with open(path2) as f:
      print len(f.readlines())
# Out:
# 20390199

# %%
with open(path1) as myfile:
    head = [next(myfile) for x in xrange(10)]
print head
# Out:
# ['act_date           ^source^pos_ctry^pos_iata^pos_oid  ^rloc          ^cre_date           ^duration^distance^dep_port^dep_city^dep_ctry^arr_port^arr_city^arr_ctry^lst_port^lst_city^lst_ctry^brd_port^brd_city^brd_ctry^off_port^off_city^off_ctry^mkt_port^mkt_city^mkt_ctry^intl^route          ^carrier^bkg_class^cab_class^brd_time           ^off_time           ^pax^year^month^oid      \n', '2013-03-05 00:00:00^1A    ^DE      ^a68dd7ae953c8acfb187a1af2dcbe123^1a11ae49fcbf545fd2afc1a24d88d2b7^ea65900e72d71f4626378e2ebd298267^2013-02-22 00:00:00^1708^0^ZRH     ^ZRH     ^CH      ^LHR     ^LON     ^GB      ^ZRH     ^ZRH     ^CH      ^LHR     ^LON     ^GB      ^ZRH     ^ZRH     ^CH      ^LHRZRH  ^LONZRH  ^CHGB    ^1^LHRZRH         ^VI^T        ^Y        ^2013-03-07 08:50:00^2013-03-07 11:33:37^-1^2013^3^NULL     \n', '2013-03-26 00:00:00^1A    ^US      ^e612b9eeeee6f17f42d9b0d3b79e75ca^7437560d8f276d6d05eeb806d9e7edee^737295a86982c941f1c2da9a46a14043^2013-03-26 00:00:00^135270^0^SAL     ^SAL 
# ...

# %%
data = pd.read_csv(path_1, header=0, delimiter = '^', nrows=5000)

# %%
data.head()
# Out:
#    act_date             source  pos_ctry                          pos_iata  \
# 0  2013-03-05 00:00:00  1A      DE        a68dd7ae953c8acfb187a1af2dcbe123
# 1  2013-03-26 00:00:00  1A      US        e612b9eeeee6f17f42d9b0d3b79e75ca
# 2  2013-03-26 00:00:00  1A      US        e612b9eeeee6f17f42d9b0d3b79e75ca
# 3  2013-03-26 00:00:00  1A      AU        0f984b3bb6bd06661c95529bbd6193bc
# 4  2013-03-26 00:00:00  1A      AU        0f984b3bb6bd06661c95529bbd6193bc
#
#                           pos_oid                      rloc            \
# 0  1a11ae49fcbf545fd2afc1a24d88d2b7  ea65900e72d71f4626378e2ebd298267
# 1  7437560d8f276d6d05eeb806d9e7edee  737295a86982c941f1c2da9a46a14043
# 2  7437560d8f276d6d05eeb806d9e7edee  737295a86982c941f1c2da9a46a14043
# 3  36472c6dbaf7afec9136ac40364e2794  5ecf00fdcbcec761c43dc7285253d0c1
# 4  36472c6dbaf7afec9136ac40364e2794  5ecf00fdcbcec761c43dc7285253d0c1
#
#    cre_date             duration  distance  dep_port    ...      \
# ...

# %%
data['date_trunc'] = data['cre_date           '].str[0:10]

# %%
data.columns
# Out:
# Index([u'act_date           ', u'source', u'pos_ctry', u'pos_iata',
#        u'pos_oid  ', u'rloc          ', u'cre_date           ', u'duration',
#        u'distance', u'dep_port', u'dep_city', u'dep_ctry', u'arr_port',
#        u'arr_city', u'arr_ctry', u'lst_port', u'lst_city', u'lst_ctry',
#        u'brd_port', u'brd_city', u'brd_ctry', u'off_port', u'off_city',
#        u'off_ctry', u'mkt_port', u'mkt_city', u'mkt_ctry', u'intl',
#        u'route          ', u'carrier', u'bkg_class', u'cab_class',
#        u'brd_time           ', u'off_time           ', u'pax', u'year',
#        u'month', u'oid      ', u'date_trunc'],
#       dtype='object')

# %%
data['brd_time           '].describe()
# Out:
# count                 1000000
# unique                 167848
# top       2013-09-26 12:55:00
# freq                      133
# Name: brd_time           , dtype: object

# %%
# Not a good idea with my computer, it completely freezes...
data = pd.read_csv(path1, header=0, delimiter = '^')
# Out:
# Exception KeyboardInterrupt in 'zmq.backend.cython.message.Frame.__dealloc__' ignored
# ERROR: Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
#
# KeyboardInterrupt
# Traceback (most recent call last):

# %%
# So for starter, that will do :
data = pd.read_csv(path_1, header=0, delimiter = '^', nrows=1000000)

# %% [markdown]
# ### Exercise 2 : top destinations

# %%
# get airport info from the github repo GeoBases to associate countries and airport names, might be the opposite for long and lat
airport = pd.read_csv('C:\Users\dmessedi\Desktop\Amadeus\\airports.csv', header=None, delimiter= '^')
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-8-8e9b2d87fe52> in <module>()
#       1 # get airport info from the github repo GeoBases to associate countries and airport names, might be the opposite for long and lat
# ----> 2 airport = pd.read_csv('C:\Users\dmessedi\Desktop\Amadeus\\airports.csv', header=None, delimiter= '^')
#
# ...

# %%
airport = pd.read_csv('/Users/dalilamessedi/Desktop/Data/airports.csv', header=None, delimiter= '^')

# %%
airport.head()
# Out:
#      0                                1    2   3                     4  \
# 0  AUH  Abu Dhabi International Airport  AUH  AE  United Arab Emirates
# 1  AZI         Abu Dhabi Bateen Airport  AUH  AE  United Arab Emirates
# 2  AAN     Al Ain International Airport  AAN  AE  United Arab Emirates
# 3  DXB      Dubai International Airport  DXB  AE  United Arab Emirates
# 4  FJR                         Fujairah  FJR  AE  United Arab Emirates
#
#            5          6
# 0  24.432972  54.651138
# 1  24.428333  54.458084
# 2  24.261667  55.609167
# 3  25.252778  55.364444
# 4  25.112225  56.323964

# %%
airport = airport.drop(2, 1)

# %%
airport.columns = ['airp_code', 'airp_name', 'country_code', 'country_name', 'long', 'lat']

# %%
airport.head()
# Out:
#   airp_code                        airp_name country_code  \
# 0       AUH  Abu Dhabi International Airport           AE
# 1       AZI         Abu Dhabi Bateen Airport           AE
# 2       AAN     Al Ain International Airport           AE
# 3       DXB      Dubai International Airport           AE
# 4       FJR                         Fujairah           AE
#
#            country_name       long        lat
# 0  United Arab Emirates  24.432972  54.651138
# 1  United Arab Emirates  24.428333  54.458084
# 2  United Arab Emirates  24.261667  55.609167
# 3  United Arab Emirates  25.252778  55.364444
# 4  United Arab Emirates  25.112225  56.323964

# %%
airport = airport.rename(columns= {'airp_code': 'arr_port'})

# %%
airport.arr_port = airport.arr_port.astype(str)
data.arr_port = data.arr_port.astype(str)

# %%
def get_N_first(N):
    print pd.merge((data[['arr_port', 'pax']].groupby(['arr_port'])['pax'].sum().order('pax', ascending=False)[0:N].reset_index()), 
                   airport[['arr_port', 'country_name']], on='arr_port', how='left')

# %%
airport[['arr_port', 'country_name']]
# Out:
#      arr_port          country_name
# 0         AUH  United Arab Emirates
# 1         AZI  United Arab Emirates
# 2         AAN  United Arab Emirates
# 3         DXB  United Arab Emirates
# 4         FJR  United Arab Emirates
# 5         RKT  United Arab Emirates
# 6         SHJ  United Arab Emirates
# 7         KBL           Afghanistan
# 8         FAH           Afghanistan
# 9         FBD           Afghanistan
# 10        HEA           Afghanistan
# 11        JAA           Afghanistan
# 12        MZR           Afghanistan
# 13        ANU   Antigua and Barbuda
# 14        AXA              Anguilla
# 15        TIA               Albania
# 16        EVN               Armenia
# 17        LWN               Armenia
# 18        SXM  Netherlands Antilles
# 19        EUX  Netherlands Antilles
# 20        BON  Netherlands Antilles
# 21        CUR  Netherlands Antilles
# 22        BUG                Angola
# 23        CAB                Angola
# 24        NOV                Angola
# ...

# %%
(data[['arr_port', 'pax']].groupby(['arr_port'])['pax'].sum().order('pax', ascending=False)[0:5].reset_index())
# Out:
#    arr_port   pax
# 0  LHR       8881
# 1  MCO       7093
# 2  LAX       7053
# 3  LAS       6963
# 4  JFK       6627

# %%
# So of course these won't be the expected output since the whole data isn't here
get_N_first(10)
# Out:
#    arr_port   pax country_name
# 0  LHR       8881          NaN
# 1  MCO       7093          NaN
# 2  LAX       7053          NaN
# 3  LAS       6963          NaN
# 4  JFK       6627          NaN
# 5  CDG       6449          NaN
# 6  BKK       5946          NaN
# 7  MIA       5815          NaN
# 8  SFO       5800          NaN
# 9  DXB       5559          NaN
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: FutureWarning: order is deprecated, use sort_values(...)
#   from ipykernel import kernelapp as app

# %%
airport[airport['arr_port']=='LHR']
# Out:
#     arr_port                airp_name country_code    country_name       long  \
# 900      LHR  London Heathrow Airport           GB  United Kingdom  51.471146
#
#          lat
# 900 -0.45649

# %% [markdown]
# I don't get why this is not working, I'll switch to something else, hopefully it'll be clearer when I come back to it....

# %% [markdown]
# ### Exercise 3 : monthly number of searches

# %%
# For quick tests, the whole data later
searches = pd.read_csv(path2, header=0, delimiter = '^', nrows=1000000)
# Out:
# C:\Users\dmessedi\AppData\Local\Continuum\Anaconda\lib\site-packages\pandas\io\parsers.py:1170: DtypeWarning: Columns (44) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = self._reader.read(nrows)

# %%
searches = pd.read_csv(path_2, header=0, delimiter = '^', nrows=1000000)
# Out:
# //anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2902: DtypeWarning: Columns (44) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
searches.head()
# Out:
#          Date      Time TxnCode                          OfficeID Country  \
# 0  2013-01-01  20:25:57     MPT  624d8c3ac0b3a7ca03e3c167e0f48327      DE
# 1  2013-01-01  10:15:33     MPT  b0af35b31588dc4ab06d5cf2986e8e02      MD
# 2  2013-01-01  18:04:49     MPT  3561a60621de06ab1badc8ca55699ef3      US
# 3  2013-01-01  17:42:40     FXP  1864e5e8013d9414150e91d26b6a558b      SE
# 4  2013-01-01  17:48:29     MPT  1ec336348f44207d2e0027dc3a68c118      NO
#
#   Origin Destination  RoundTrip  NbSegments Seg1Departure      ...        \
# 0    TXL         AUH          1           2           TXL      ...
# 1    ATH         MIL          0           1           ATH      ...
# 2    ICT         SFO          1           2           ICT      ...
# 3    RNB         ARN          0           1           RNB      ...
# 4    OSL         MAD          1           2           OSL      ...
#
#   Seg6Arrival Seg6Date Seg6Carrier Seg6BookingCode    From IsPublishedForNeg  \
# ...

# %%
# Dataframe with only the info we're interested in, so that the processes are faster 
searches_spain = searches[(searches['Destination']=='MAD') | (searches['Destination']=='AGP') | (searches['Destination']=='BCN')]

# %%
searches_spain.head()
# Out:
#            Date      Time TxnCode                          OfficeID Country  \
# 4    2013-01-01  17:48:29     MPT  1ec336348f44207d2e0027dc3a68c118      NO
# 93   2013-01-01  20:15:57     MPT  624d8c3ac0b3a7ca03e3c167e0f48327      DE
# 113  2013-01-01  23:40:53     FXX  0028c46214bc260eb3011510a898cd42      ES
# 147  2013-01-01  15:35:53     MPT  63d35a15724f95939e6d0dd0ca39be16      DE
# 151  2013-01-01  10:46:21     MPT  50c54b52322080d2c257390f714f91bd      ES
#
#     Origin Destination  RoundTrip  NbSegments Seg1Departure      ...        \
# 4      OSL         MAD          1           2           OSL      ...
# 93     FRA         AGP          1           2           FRA      ...
# 113    ALC         BCN          0           2           ALC      ...
# 147    HHN         AGP          0           1           HHN      ...
# 151    FRA         MAD          0           1           FRA      ...
#
#     Seg6Arrival Seg6Date Seg6Carrier Seg6BookingCode    From  \
# ...

# %% [markdown]
# Seems OK ...

# %%
searches_spain['month'] = searches_spain.Date.str[5:7]
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
searches_spain.head()
# Out:
#            Date      Time TxnCode                          OfficeID Country  \
# 4    2013-01-01  17:48:29     MPT  1ec336348f44207d2e0027dc3a68c118      NO
# 93   2013-01-01  20:15:57     MPT  624d8c3ac0b3a7ca03e3c167e0f48327      DE
# 113  2013-01-01  23:40:53     FXX  0028c46214bc260eb3011510a898cd42      ES
# 147  2013-01-01  15:35:53     MPT  63d35a15724f95939e6d0dd0ca39be16      DE
# 151  2013-01-01  10:46:21     MPT  50c54b52322080d2c257390f714f91bd      ES
#
#     Origin Destination  RoundTrip  NbSegments Seg1Departure  ...  Seg6Date  \
# 4      OSL         MAD          1           2           OSL  ...       NaN
# 93     FRA         AGP          1           2           FRA  ...       NaN
# 113    ALC         BCN          0           2           ALC  ...       NaN
# 147    HHN         AGP          0           1           HHN  ...       NaN
# 151    FRA         MAD          0           1           FRA  ...       NaN
#
# ...

# %%
import numpy as np

# %%
searches_agg = searches_spain.groupby(['Destination', 'month']).agg(np.size).reset_index()[['Destination', 'month', 'Time']]

# %%
searches_agg
# Out:
#    Destination month  Time
# 0          AGP    01   507
# 1          AGP    02   441
# 2          AGP    03   561
# 3          AGP    04   435
# 4          AGP    05   570
# 5          AGP    06   417
# 6          AGP    07   468
# 7          AGP    08   414
# 8          AGP    09   429
# 9          AGP    10   271
# 10         AGP    11   228
# 11         AGP    12   132
# 12         BCN    01  1551
# 13         BCN    02  1491
# 14         BCN    03  1608
# 15         BCN    04  1644
# 16         BCN    05  1512
# 17         BCN    06  1395
# 18         BCN    07  1539
# 19         BCN    08  1425
# 20         BCN    09  1233
# 21         BCN    10   839
# 22         BCN    11   708
# 23         BCN    12   550
# 24         MAD    01  1275
# 25         MAD    02  1200
# 26         MAD    03  1299
# 27         MAD    04  1329
# 28         MAD    05  1386
# 29         MAD    06  1200
# 30         MAD    07  1209
# 31         MAD    08  1149
# 32         MAD    09  1113
# ...

# %%
BCN = searches_agg[searches_agg['Destination']=='BCN']

# %%
BCN
# Out:
#    Destination month  Time
# 12         BCN    01  1551
# 13         BCN    02  1491
# 14         BCN    03  1608
# 15         BCN    04  1644
# 16         BCN    05  1512
# 17         BCN    06  1395
# 18         BCN    07  1539
# 19         BCN    08  1425
# 20         BCN    09  1233
# 21         BCN    10   839
# 22         BCN    11   708
# 23         BCN    12   550

# %%
BCN[['month', 'Time']].plot()

# %%
BCN.set_index('month').plot()

# %%
searches_agg[searches_agg['Destination']=='MAD'].set_index('month').plot()

# %%
plt.figure()
with pd.plot_params.use('x_compat', True):
    searches_agg[searches_agg['Destination']=='MAD'].set_index('month').Time.plot(color='r')
    searches_agg[searches_agg['Destination']=='BCN'].set_index('month').Time.plot(color='g')
    searches_agg[searches_agg['Destination']=='AGP'].set_index('month').Time.plot(color='b')

# %% [markdown]
# ### Fourth Exercise : bookings and searches matches

# %%
data.columns
# Out:
# Index([u'act_date           ', u'source', u'pos_ctry', u'pos_iata',
#        u'pos_oid  ', u'rloc          ', u'cre_date           ', u'duration',
#        u'distance', u'dep_port', u'dep_city', u'dep_ctry', u'arr_port',
#        u'arr_city', u'arr_ctry', u'lst_port', u'lst_city', u'lst_ctry',
#        u'brd_port', u'brd_city', u'brd_ctry', u'off_port', u'off_city',
#        u'off_ctry', u'mkt_port', u'mkt_city', u'mkt_ctry', u'intl',
#        u'route          ', u'carrier', u'bkg_class', u'cab_class',
#        u'brd_time           ', u'off_time           ', u'pax', u'year',
#        u'month', u'oid      '],
#       dtype='object')

# %%
searches.merge(data[['dep_port', 'arr_port', 'pos_oid  ', 'date_trunc', 'pax']], how='left', left_on = ['Origin', 'Destination', 'OfficeID', 'Date'], right_on = ['dep_port', 'arr_port', 'pos_oid  ', 'date_trunc'])
# Out:
#               Date      Time TxnCode                          OfficeID  \
# 0       2013-01-01  20:25:57     MPT  624d8c3ac0b3a7ca03e3c167e0f48327
# 1       2013-01-01  10:15:33     MPT  b0af35b31588dc4ab06d5cf2986e8e02
# 2       2013-01-01  18:04:49     MPT  3561a60621de06ab1badc8ca55699ef3
# 3       2013-01-01  17:42:40     FXP  1864e5e8013d9414150e91d26b6a558b
# 4       2013-01-01  17:48:29     MPT  1ec336348f44207d2e0027dc3a68c118
# 5       2013-01-01  22:00:28     MPT  3561a60621de06ab1badc8ca55699ef3
# 6       2013-01-01  10:47:14     MPT  d327ca6e35cc6732d4709828327ac7c1
# 7       2013-01-01  23:39:49     MPT  38a3abb0a28e3f00fa79a11f552a5052
# 8       2013-01-01  17:08:46     MPT  c8daef4f8bf73a61aa2c928705f7b82d
# 9       2013-01-01  19:57:57     MPT  28d7a8c95e4db88589d3d35b66920e78
# 10      2013-01-01  18:01:31     MPT  b2771a31dc32d1e4af0ea7d758b8442b
# 11      2013-01-01  09:32:18     FFP  53aea156edeed571bbc473c82b01ac4b
# ...

# %% [markdown]
# Just like for the second exercise, I don't get why this is not working, maybe some type mismatch or just a wrong
# assumption regarding the columns I used...

# %%
# In Hive, this is how I would do it (I seem to have issues with pandas and left joins lately), 
# I'm assuming the creation date cre_date is appropriate to compare to the searches, and pos_id matches OfficeID 
# but not sure this is true and also this is all I should be matching...
SELECT 
S.*
B.pax is not null AS booking_match
FROM searches as S
LEFT OUTER JOIN bookings B 
ON (S.Origin = B.dep_port AND S.Destination = B.arr_port AND S.OfficeID = B.pos_oid AND S.Date = B.date_trunc)
